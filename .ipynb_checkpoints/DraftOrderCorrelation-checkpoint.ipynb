# %%
# Dependencies
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define League ID and year
league_id = 730129

# %%
# Define year range
years = [2018, 2019, 2020, 2021]

# %%
# Define the URL with our parameters
url = f'https://fantasy.espn.com/apis/v3/games/ffl/leagueHistory/{league_id}/?seasonId='

# Initialize empty list to hold each year's JSON response
performance = []

for year in years:
    
    # Pull team data from the URL 
    performance_response = requests.get(url + str(year), params={"view": "mTeam"})

    # Transform the response into a JSON file
    performance_json = performance_response.json()
    
    # Append each year to performance list
    performance.append(performance_json)

# %%
# Initialize empty lists to hold ids, W %
ids = []

win_percentage = []

# %%
# Loop through the JSON and populate ids and W % lists
for i in range(len(performance)):
        for j in range(0, 10):
            try:
                ids.append(performance[i][0]['teams'][j]['id'])
                win_percentage.append(performance[i][0]['teams'][j]['record']['overall']['percentage'])
            except:
                pass

# %%
# Create dictionary to hold performance data
data = {'Team ID' : ids, 'Win Percentage' : win_percentage}

# Load the dictionary into the DataFrame
performance_df = pd.DataFrame(data)

# %%
performance_df
# Out:
#     Team ID  Win Percentage
# 0         1        0.833333
# 1         2        0.333333
# 2         3        0.666667
# 3         4        0.500000
# 4         5        0.166667
# 5         6        0.416667
# 6         7        0.500000
# 7         8        0.583333
# 8         1        0.416667
# 9         2        0.583333
# 10        3        0.583333
# 11        4        0.750000
# 12        5        0.083333
# 13        6        0.500000
# 14        7        0.166667
# 15        8        0.833333
# 16        9        0.583333
# 17       10        0.500000
# 18        1        0.750000
# 19        2        0.500000
# 20        3        0.666667
# 21        4        0.166667
# 22        8        0.250000
# 23       10        0.666667
# 24       11        0.833333
# 25       12        0.333333
# 26       13        0.500000
# 27       14        0.333333
# 28        1        0.461538
# 29        2        0.538462
# 30        3        0.461538
# 31        4        0.461538
# 32        8        0.769231
# 33       10        0.461538
# 34       11        0.461538
# 35       12        0.307692
# 36       13        0.615385
# 37       14        0.461538

# %%
draft = []

for year in years:
    # Reuse the URL variable to call the draft view
    draft_response = requests.get(url, params={"view" : "mDraftDetail"})

    # Convert the response to a JSON
    draft_json = draft_response.json()
    
    # Append each year's draft data to the list
    draft.append(draft_json)

# %%
# Initialize the empty lists for ids and draft position
ids = []

draft_position = []

# %%
# Loop through the JSON and populate ids and draft position
for j in range(len(draft)):
    for i in range(0,10):
        try:
            ids.append(draft[0][j]['draftDetail']['picks'][i]['teamId'])
            draft_position.append(draft[0][j]['draftDetail']['picks'][i]['id'])
        except:
            pass

# %%
# SPECIFIC TO MY LEAGUE
# We did an 8 man league the first year, removing the 9th and 10th  from the lists 

del ids[8:10]
del draft_position[8:10]

# %%
# Create a dictionary to hold the draft data
data = {'Team ID' : ids, 'Draft Position' : draft_position}

# Load the dictionary into a pandas DataFrame
draft_df = pd.DataFrame(data)

# %%
draft_df
# Out:
#     Team ID  Draft Position
# 0         3               1
# 1         4               2
# 2         1               3
# 3         2               4
# 4         8               5
# 5         7               6
# 6         6               7
# 7         5               8
# 8         1               1
# 9         8               2
# 10        3               3
# 11        4               4
# 12        2               5
# 13        6               6
# 14        7               7
# 15        5               8
# 16        9               9
# 17       10              10
# 18        4               1
# 19        2               2
# 20       14               3
# 21       11               4
# 22        3               5
# 23       10               6
# 24        1               7
# 25       13               8
# 26        8               9
# 27       12              10
# 28       11               1
# 29        1               2
# 30        4               3
# 31        8               4
# 32       12               5
# 33       14               6
# 34       10               7
# 35       13               8
# 36        3               9
# 37        2              10

# %%
df = pd.merge(draft_df, performance_df, how='left')

# %%
df
# Out:
#      Team ID  Draft Position  Win Percentage
# 0          3               1        0.666667
# 1          3               1        0.583333
# 2          3               1        0.666667
# 3          3               1        0.461538
# 4          4               2        0.500000
# ..       ...             ...             ...
# 113        3               9        0.461538
# 114        2              10        0.333333
# 115        2              10        0.583333
# 116        2              10        0.500000
# 117        2              10        0.538462
#
# [118 rows x 3 columns]

# %%
# Drop the Team ID column
df = df[['Draft Position', 'Win Percentage']]

# %%
# Average win percentage by draft position
win_percentage_by_draft_position = df.groupby(df['Draft Position']).mean()

# Sort by Win Percentage
win_percentage_by_draft_position.sort_values(by=['Win Percentage'], ascending=False)
# Out:
#                 Win Percentage
# Draft Position
# 9                     0.599715
# 1                     0.572344
# 2                     0.545673
# 4                     0.540293
# 3                     0.536630
# 5                     0.529304
# 7                     0.515734
# 10                    0.469373
# 6                     0.445157
# 8                     0.341346

# %%
# Calculate the average Win Percentage by draft position
average_win_percentage = win_percentage_by_draft_position['Win Percentage'].mean()

# Add a new column that shows the delta from average win percentage by draft position
for i in win_percentage_by_draft_position:
    win_percentage_by_draft_position['+/- From Average Draft Position'] = win_percentage_by_draft_position['Win Percentage'] - average_win_percentage

# %%
# Sort descending by delta from average draft position
win_percentage_by_draft_position.sort_values(by=['+/- From Average Draft Position'], ascending=False)
# Out:
#                 Win Percentage  +/- From Average Draft Position
# Draft Position
# 9                     0.599715                         0.090158
# 1                     0.572344                         0.062787
# 2                     0.545673                         0.036116
# 4                     0.540293                         0.030736
# 3                     0.536630                         0.027073
# 5                     0.529304                         0.019747
# 7                     0.515734                         0.006177
# 10                    0.469373                        -0.040184
# 6                     0.445157                        -0.064400
# 8                     0.341346                        -0.168211

# %%
# Make a bar chart of delta from average draft position
plt.bar(win_percentage_by_draft_position.index, win_percentage_by_draft_position['+/- From Average Draft Position']);
plt.title("+/- Average Win Percentage by Draft Position")
plt.xlabel("Draft Position");
plt.ylabel("+/- Average Win Percentage");
plt.savefig("Win Percentage by Draft Position")
